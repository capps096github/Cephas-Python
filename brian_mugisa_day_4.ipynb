# %%
import pandas as pd

# Read the data from the file
health_ds = pd.read_csv("health.csv")

# print the data on screen
# print(health_ds)

# show null values
# health_ds.isnull().sum()

# mean, median, mode
mean = health_ds["Calories"].mean()

# print the mean
# print(mean)

median = health_ds["Calories"].median()
mode = health_ds["Calories"].mode()


# menu
selected_index = input(f"What do you want to replace the null values with? \n  1. Mean ({mean}) \n  2. Median ({median}) \n  3. Mode of the Dataset ({mode}) \nInput accepted values: 1, 2, 3 \n")

# if statements
if selected_index == "1":
    print(f"Replaced null values with  Mean: {mean}\n ")
    # fill in the missing values with the mean
    health_ds.fillna(mean, inplace=True)
elif selected_index == "2":
    print(f"Replaced null values with  Median: {median}\n ")
    # fill in the missing values with the median
    health_ds.fillna(median, inplace=True)
  
elif selected_index == "3":
    print(f"Replaced null values with  Mode: {mode}\n ")
    # fill in the missing values with the mode
    health_ds.fillna(mode, inplace=True)

else:
    print("Invalid input")

# show the new data set
print(health_ds.to_string())
# Out:
# Replaced null values with  Median: 318.6
#
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112     318.6
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# 23         45    105       132     246.0
# 24         60    102       126     334.5
# 25         60    100       120     250.0
# 26         60     92       118     241.0
# 27         60    103       132     318.6
# 28         60    100       132     280.0
# 29         60    102       129     380.3
# 30         60     92       115     243.0
# 31         45     90       112     180.1
# 32         60    101       124     299.0
# 33         60     93       113     223.0
# 34         60    107       136     361.0
# 35         60    114       140     415.0
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 39         45    104       129     266.0
# 40         45     90       112     180.1
# 41         60     98       126     286.0
# 42         60    100       122     329.4
# 43         60    111       138     400.0
# 44         60    111       131     397.0
# 45         60     99       119     273.0
# 46         60    109       153     387.6
# 47         45    111       136     300.0
# 48         45    108       129     298.0
# 49         60    111       139     397.6
# 50         60    107       136     380.2
# 51         80    123       146     643.1
# 52         60    106       130     263.0
# 53         60    118       151     486.0
# 54         30    136       175     238.0
# 55         60    121       146     450.7
# 56         60    118       121     413.0
# 57         45    115       144     305.0
# 58         20    153       172     226.4
# 59         45    123       152     321.0
# 60        210    108       160    1376.0
# 61        160    110       137    1034.4
# 62        160    109       135     853.0
# 63         45    118       141     341.0
# 64         20    110       130     131.4
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 68         20    106       136     110.4
# 69        300    108       143    1500.2
# 70        150     97       129    1115.0
# 71         60    109       153     387.6
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 74         45    114       146     304.0
# 75         90     98       125     563.2
# 76         45    105       134     251.0
# 77         45    110       141     300.0
# 78        120    100       130     500.4
# 79        270    100       131    1729.0
# 80         30    159       182     319.2
# 81         45    149       169     344.0
# 82         30    103       139     151.1
# 83        120    100       130     500.0
# 84         45    100       120     225.3
# 85         30    151       170     300.0
# 86         45    102       136     234.0
# 87        120    100       157    1000.1
# 88         45    129       103     242.0
# 89         20     83       107      50.3
# 90        180    101       127     600.1
# 91         45    107       137     318.6
# 92         30     90       107     105.3
# 93         15     80       100      50.5
# 94         20    150       171     127.4
# 95         20    151       168     229.4
# 96         30     95       128     128.2
# 97         25    152       168     244.2
# 98         30    109       131     188.2
# 99         90     93       124     604.1
# 100        20     95       112      77.7
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 104        30     92       108      92.7
# 105        30     93       128     124.0
# 106       180     90       120     800.3
# 107        30     90       120      86.2
# 108        90     90       120     500.3
# 109       210    137       184    1860.4
# 110        60    102       124     325.2
# 111        45    107       124     275.0
# 112        15    124       139     124.2
# 113        45    100       120     225.3
# 114        60    108       131     367.6
# 115        60    108       151     351.7
# 116        60    116       141     443.0
# 117        60     97       122     277.4
# 118        60    105       125     318.6
# 119        60    103       124     332.7
# 120        30    112       137     193.9
# 121        45    100       120     100.7
# 122        60    119       169     336.7
# 123        60    107       127     344.9
# 124        60    111       151     368.5
# 125        60     98       122     271.0
# 126        60     97       124     275.3
# 127        60    109       127     382.0
# 128        90     99       125     466.4
# 129        60    114       151     384.0
# 130        60    104       134     342.5
# 131        60    107       138     357.5
# 132        60    103       133     335.0
# 133        60    106       132     327.5
# 134        60    103       136     339.0
# 135        20    136       156     189.0
# 136        45    117       143     317.7
# 137        45    115       137     318.0
# 138        45    113       138     308.0
# 139        20    141       162     222.4
# 140        60    108       135     390.0
# 141        60     97       127     318.6
# 142        45    100       120     250.4
# 143        45    122       149     335.4
# 144        60    136       170     470.2
# 145        45    106       126     270.8
# 146        60    107       136     400.0
# 147        60    112       146     361.9
# 148        30    103       127     185.0
# 149        60    110       150     409.4
# 150        60    106       134     343.0
# 151        60    109       129     353.2
# 152        60    109       138     374.0
# 153        30    150       167     275.8
# 154        60    105       128     328.0
# 155        60    111       151     368.5
# 156        60     97       131     270.4
# 157        60    100       120     270.4
# 158        60    114       150     382.8
# 159        30     80       120     240.9
# 160        30     85       120     250.4
# 161        45     90       130     260.4
# 162        45     95       130     270.0
# 163        45    100       140     280.9
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
import pandas as pd

# Read the data from the file
new_health_ds = pd.read_csv("health.csv").dropna()

# print the new data set
print(new_health_ds)

# show null values
new_health_ds.isnull().sum()

# %%
#Perform Operations on the data set in Python
import pandas as pd

# Read the data from the file
new_health_ds = pd.read_csv("health.csv").dropna()

# print the new data set
print(new_health_ds)

# show null values
new_health_ds.isnull().sum()

# dataset info
new_health_ds.info()

# show the first 5 rows
new_health_ds.head()

# show the last 5 rows
new_health_ds.tail()

# show the first 10 rows
new_health_ds.head(10)

# show the last 10 rows
new_health_ds.tail(10)

# describe the data set
new_health_ds.describe()

# show the data types
new_health_ds.dtypes

# get the column names
new_health_ds.columns

# get the index
new_health_ds.index

# get the values
new_health_ds.values

# get the shape
new_health_ds.shape

# get the size
new_health_ds.size

# get the mean
new_health_ds.mean()

# get the median
new_health_ds.median()

# get the mode
new_health_ds.mode()

# get the standard deviation
new_health_ds.std()

# get the variance
new_health_ds.var()

# get the sum
new_health_ds.sum()

# get the product
new_health_ds.prod()

# get the min
new_health_ds.min()

# get the max
new_health_ds.max()

# get the count
new_health_ds.count()

# get the cumsum
new_health_ds.cumsum()

# get the cumprod
new_health_ds.cumprod()

# fill in the missing values
new_health_ds.fillna(0)

# %%
import pandas as pd

# Read the data from the file
new_health_ds = pd.read_csv("health.csv").dropna()

# print the new data set
print(new_health_ds)

# add a date column of today
new_health_ds["Date"] = pd.to_datetime("today").date()

# print the new data set
print(new_health_ds.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [164 rows x 4 columns]
#      Duration  Pulse  Maxpulse  Calories        Date
# 0          60    110       130     409.1  2022-09-08
# 1          60    117       145     479.0  2022-09-08
# 2          60    103       135     340.0  2022-09-08
# 3          45    109       175     282.4  2022-09-08
# 4          45    117       148     406.0  2022-09-08
# 5          60    102       127     300.0  2022-09-08
# 6          60    110       136     374.0  2022-09-08
# 7          45    104       134     253.3  2022-09-08
# 8          30    109       133     195.1  2022-09-08
# 9          60     98       124     269.0  2022-09-08
# 10         60    103       147     329.3  2022-09-08
# 11         60    100       120     250.7  2022-09-08
# 167        75    120       150     320.4  2022-09-08
# 168        75    125       150     330.4  2022-09-08

# %%
import pandas as pd

date_ds = pd.read_csv("date_dataset.csv")

# print the dataset
# print(date_ds.to_string())

# check for duplicates
# date_ds.duplicated().sum()

# check duplicates in the date column
date_ds["Duration"].duplicated().sum()

# drop duplicates
date_ds.drop_duplicates(inplace=True)

# %%
# Data Visulaization using pandas
import pandas as pd

# read the admissions data set csv
admissions_ds = pd.read_csv('admissions.csv')

# describe the data set : this shows the descriptions of the data to understand
# what excatly is in your data
# admissions_ds.describe()

# get colums
# admissions_ds.columns

# get data types
admissions_ds.dtypes

# check for null values
# admissions_ds.isnull().values.any().sum()
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
# PIe Chart Example

import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#Correlation in Python
import pandas as pd
import numpy as np # from pip install numpy
import seaborn as sns # from pip install seaborn
import matplotlib.pyplot as plt # from pip install matplotlib


# Apply the default theme
# sns.set_theme(palette="Paired")

# read the admissions data set csv
admissions_ds = pd.read_csv('admissions.csv')

# show a pair plot us
# sns.pairplot(admissions_ds)
# plt.show()



# You can customize the colors in your heatmap with the cmap parameter of the heatmap() function in seaborn
# map: The mapping from data values to color space. center: The value at which to center the colormap when plotting divergent data. annot: If True, write the data value in each cell. fmt: String formatting code to use when adding annotations. linewidths:
# cmap: The mapping from data values to color space. center: The value at which to center the colormap when plotting divergent data. annot: If True, write the data value in each cell. fmt: String formatting code to use when adding annotations. linewidths:


# show a heatmap of the correlation
# sns.heatmap(admissions_ds.corr(), cmap=sns.color_palette("tab10", as_cmap=True), annot=True)
# sns.heatmap(admissions_ds.corr(), cmap=sns.color_palette("Paired", as_cmap=True), annot=True)
sns.heatmap(admissions_ds.corr(), annot=True)

# set the title
plt.title("Correlation Heatmap")

# set figure size
plt.figure(figsize=(100, 100))

# show the plot
plt.show()

# %%
# Pie Charts in Python
import pandas as pd
import numpy as np # from pip install numpy
import seaborn as sns # from pip install seaborn
import matplotlib.pyplot as plt # from pip install matplotlib

# read the music data set csv
music_ds = pd.read_csv('dummy.csv')

# get the column names and change them to a list of labels
labels = tuple(music_ds["genre"].tolist())

# get the sizes of the data set from the age column and change them to a list of sizes integers
sizes =  music_ds['age'].tolist()

# get the explode only explode the first and second column and this is based on the length of the labels and convert it to a tuple
explode = (0.1, 0.1)+ tuple([0 for i in range(len(labels)-2)]) 

# Email: jeff.geoff.mis@gmail.com cc. jeff.geoff.cis@gmail.com

# colors from the data set colors column
colors =  music_ds['colors'].tolist()

# Colors can be
# b: blue.
# g: green.
# r: red.
# c: cyan.
# m: magenta.
# y: yellow.
# k: black.
# w: white.


fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels,shadow=True,autopct='%1.1f%%', colors =colors,
         startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# set the title
plt.title("Music Genre Pie Chart")

# set the size to 100 by 100
plt.figure(figsize=(100, 100))

# show the plot
plt.show()
# Out:
# ['cyan', 'yellow', 'red', 'green', 'lime']
